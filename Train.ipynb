# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
from neuroner import neuromodel
from shutil import copyfile, copy
import random
import os
# Out:
# Using TensorFlow backend.

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.Session(config=config)
set_session(sess)  # set this TensorFlow session as the default session for Keras

# %% [markdown]
# ### Functions in charge of split the data into an indicate percent

# %%
def make_dev_split(data, devPercent):
    index = int(round(devPercent*len(data)))
    shuffled = data[:]
    random.shuffle(shuffled)
    return shuffled[index:], shuffled[:index]

# %%
def make_train_valid_files(data_path, valid_percent):
    train_dir = os.path.join(os.getcwd(),"data/train/")
    valid_dir = os.path.join(os.getcwd(),"data/valid/")
    file_names = list(set([os.path.splitext(os.path.join(os.path.abspath(data_path), path))[0] for path in os.listdir(data_path)]))
    train, valid = make_dev_split(file_names, valid_percent)
    for path in train:
        copyfile(path+".ann", train_dir+os.path.basename(path)+".ann")
        copyfile(path+".txt", train_dir+os.path.basename(path)+".txt")    
    for path in valid:
        copyfile(path+".ann", valid_dir+os.path.basename(path)+".ann")
        copyfile(path+".txt", valid_dir+os.path.basename(path)+".txt")

# %% [markdown]
# ### Function in charge of postprocessing the files resulting from the prediction of the NeuroNER model.

# %%
def postprocess(input_file, output_file, clear_ending_points=False, clear_prefixes = False, prefixes = []):
    file = open(output_file, mode='w', encoding='utf8')
    for x in open(input_file).readlines():
        if (len(x)>1):
            token, doc, start, end, e0, e1 = x.split()
            if (clear_ending_points and len(token)>1 and token[-1]=='.'):
                token = token[:-1]
                end = str(int(end)-1)
            if (clear_prefixes and len(token)>1 and token[-1]!='.'):
                for prefix in prefixes:
                    if prefix in token:
                        token = token[len(prefix):]
                        start = str(int(start)+len(prefix))
            file.write(token+" "+doc+" "+start+" "+end+" "+e0+" "+e1+"\n")
        else:
            file.write("\n")
    file.close()

# %% [markdown]
# ## Split de datasets
#
# Just in case you need to split de dataset into a training set and validation set

# %%
# data_path = './data/'
# make_train_valid_files(data_path, 0.3)

# %% [markdown]
# ## Instantiating and training the NeuroNER model
# All parameters are taken from the file "parameters.ini". These parameters can be modified when a NeuroNER model is instanciated.

# %%
nn = neuromodel.NeuroNER()
# Out:
# {'train_model': 1, 'use_pretrained_model': 0, 'pretrained_model_folder': '', 'output_scores': 0, 'dataset_text_folder': './data/', 'main_evaluation_mode': 'token', 'output_folder': './output', 'use_character_lstm': 1, 'character_embedding_dimension': 25, 'character_lstm_hidden_state_dimension': 25, 'token_pretrained_embedding_filepath': '', 'token_embedding_dimension': 300, 'token_lstm_hidden_state_dimension': 200, 'use_crf': 1, 'patience': 100, 'maximum_number_of_epochs': 100, 'optimizer': 'adam', 'learning_rate': 0.001, 'gradient_clipping_value': 5.0, 'dropout_rate': 0.5, 'number_of_cpu_threads': 8, 'number_of_gpus': 1, 'experiment_name': 'test', 'tagging_format': 'bioes', 'tokenizer': 'spacy', 'spacylanguage': 'es', 'remap_unknown_tokens_to_unk': 1, 'load_only_pretrained_token_embeddings': 0, 'check_for_lowercase': 1, 'check_for_digits_replaced_with_zeros': 1, 'freeze_token_embeddings': 0, 'debug': 0, 'verbose': 0, 'plot_format': 'png', 'reload_character_embeddings': 1, 'reload_character_lstm': 1, 'reload_token_embeddings': 1, 'reload_token_lstm': 1, 'reload_feedforward': 1, 'reload_crf': 1, 'load_all_pretrained_token_embeddings': False, 'parameters_filepath': './parameters.ini'}
# Checking compatibility between CONLL and BRAT for train_spacy set ... Done.
# Checking validity of CONLL BIOES format... Done.
# Checking compatibility between CONLL and BRAT for valid_spacy set ... Done.
# Checking validity of CONLL BIOES format... Done.
# Load dataset... done (19.82 seconds)

# %%
nn.fit()
# Out:
# Starting epoch 0
# Training completed in 0.00 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.0000    0.0000    0.0000      5545
#                     CENTRO_SALUD     0.0004    0.1379    0.0008        29
#               CORREO_ELECTRONICO     0.0091    0.6414    0.0180       474
#           EDAD_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.0018    0.0931    0.0035       376
#                           FECHAS     0.0007    0.0020    0.0010      1514
#                         HOSPITAL     0.0045    0.0455    0.0083      1100
#                 ID_ASEGURAMIENTO     0.0114    0.6224    0.0224      1160
#          ID_CONTACTO_ASISTENCIAL     0.0054    0.9870    0.0107        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000       600
# ID_TITULACION_PERSONAL_SANITARIO     0.0003    0.0007    0.0005      1398
#                      INSTITUCION     0.0014    0.0719    0.0028       320
#        NOMBRE_PERSONAL_SANITARIO     0.0024    0.0071    0.0036      3365
#         NOMBRE_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000      1561
#                       NUMERO_FAX     0.0001    0.0444    0.0003        45
#                  NUMERO_TELEFONO     0.0000    0.0000    0.0000       136
#          OTROS_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000        32
#                             PAIS     0.0000    0.0000    0.0000       731
#                        PROFESION     0.0002    0.1154    0.0005        52
#           SEXO_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000       927
#                       TERRITORIO     0.0000    0.0000    0.0000      2107
#
#                        micro avg     0.0049    0.0529    0.0090     23618
#                        macro avg     0.0017    0.1259    0.0033     23618
#                     weighted avg     0.0014    0.0529    0.0026     23618
#
# Evaluate model on the valid set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.0000    0.0000    0.0000      2786
#                     CENTRO_SALUD     0.0004    0.1818    0.0008        11
#               CORREO_ELECTRONICO     0.0094    0.6694    0.0185       245
#           EDAD_SUJETO_ASISTENCIA     0.0011    0.0010    0.0010      1030
#     FAMILIARES_SUJETO_ASISTENCIA     0.0019    0.1562    0.0038       128
#                           FECHAS     0.0021    0.0046    0.0029      1085
#                         HOSPITAL     0.0038    0.0378    0.0069       582
#                 ID_ASEGURAMIENTO     0.0108    0.6130    0.0213       584
#          ID_CONTACTO_ASISTENCIAL     0.0043    1.0000    0.0085        32
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         5
#             ID_SUJETO_ASISTENCIA     0.0003    0.0033    0.0005       304
# ID_TITULACION_PERSONAL_SANITARIO     0.0000    0.0000    0.0000       664
#                      INSTITUCION     0.0027    0.0913    0.0053       252
#        NOMBRE_PERSONAL_SANITARIO     0.0027    0.0094    0.0042      1602
#         NOMBRE_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000       782
#                       NUMERO_FAX     0.0001    0.0667    0.0002        15
#                  NUMERO_TELEFONO     0.0000    0.0000    0.0000        72
#          OTROS_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000        16
#                             PAIS     0.0000    0.0000    0.0000       349
#                        PROFESION     0.0001    0.1111    0.0001         9
#           SEXO_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000       456
#                       TERRITORIO     0.0000    0.0000    0.0000      1171
#
#                        micro avg     0.0048    0.0530    0.0088     12180
#                        macro avg     0.0018    0.1339    0.0034     12180
#                     weighted avg     0.0016    0.0530    0.0028     12180
#
# Generating plots for the train set
# Generating plots for the valid set
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/000_train.txt > ./output/_2019-05-15_14-01-31-113906/000_train.txt_conll_evaluation.txt
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/000_valid.txt > ./output/_2019-05-15_14-01-31-113906/000_valid.txt_conll_evaluation.txt
# Formatting 000_train set from CONLL to BRAT... Done.
# Formatting 000_valid set from CONLL to BRAT... Done.
# The last 0 epochs have not shown improvements on the validation set.
#
# Starting epoch 1
# Training completed in 1187.00 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9660    0.9894    0.9775      5545
#                     CENTRO_SALUD     0.5400    0.9310    0.6835        29
#               CORREO_ELECTRONICO     0.9890    0.9494    0.9688       474
#           EDAD_SUJETO_ASISTENCIA     0.9807    0.9352    0.9574      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.6734    0.7128    0.6925       376
#                           FECHAS     0.9973    0.9729    0.9850      1514
#                         HOSPITAL     0.9504    0.8882    0.9182      1100
#                 ID_ASEGURAMIENTO     0.9948    0.9966    0.9957      1160
#          ID_CONTACTO_ASISTENCIAL     0.8191    1.0000    0.9006        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9924    0.8733    0.9291       600
# ID_TITULACION_PERSONAL_SANITARIO     0.9936    1.0000    0.9968      1398
#                      INSTITUCION     0.9365    0.1844    0.3081       320
#        NOMBRE_PERSONAL_SANITARIO     0.9949    0.9935    0.9942      3365
#         NOMBRE_SUJETO_ASISTENCIA     0.9987    0.9930    0.9958      1561
#                       NUMERO_FAX     1.0000    0.1556    0.2692        45
#                  NUMERO_TELEFONO     0.7516    0.8676    0.8055       136
#          OTROS_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000        32
#                             PAIS     0.9751    0.9124    0.9428       731
#                        PROFESION     0.0000    0.0000    0.0000        52
#           SEXO_SUJETO_ASISTENCIA     0.9966    0.9612    0.9786       927
#                       TERRITORIO     0.9612    0.9530    0.9571      2107
#
#                        micro avg     0.9721    0.9490    0.9604     23618
#                        macro avg     0.7960    0.7395    0.7389     23618
#                     weighted avg     0.9694    0.9490    0.9548     23618
#
# Evaluate model on the valid set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9431    0.9824    0.9624      2786
#                     CENTRO_SALUD     0.6875    1.0000    0.8148        11
#               CORREO_ELECTRONICO     0.9655    0.9143    0.9392       245
#           EDAD_SUJETO_ASISTENCIA     0.9887    0.9359    0.9616      1030
#     FAMILIARES_SUJETO_ASISTENCIA     0.5912    0.6328    0.6113       128
#                           FECHAS     0.9947    0.8645    0.9250      1085
#                         HOSPITAL     0.9300    0.8677    0.8978       582
#                 ID_ASEGURAMIENTO     0.9965    0.9760    0.9862       584
#          ID_CONTACTO_ASISTENCIAL     0.8205    1.0000    0.9014        32
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         5
#             ID_SUJETO_ASISTENCIA     0.9815    0.8750    0.9252       304
# ID_TITULACION_PERSONAL_SANITARIO     0.9779    0.9985    0.9881       664
#                      INSTITUCION     1.0000    0.0873    0.1606       252
#        NOMBRE_PERSONAL_SANITARIO     0.9844    0.9844    0.9844      1602
#         NOMBRE_SUJETO_ASISTENCIA     0.9974    0.9949    0.9962       782
#                       NUMERO_FAX     0.2727    0.2000    0.2308        15
#                  NUMERO_TELEFONO     0.8205    0.8889    0.8533        72
#          OTROS_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000        16
#                             PAIS     0.9849    0.9341    0.9588       349
#                        PROFESION     0.0000    0.0000    0.0000         9
#           SEXO_SUJETO_ASISTENCIA     0.9887    0.9561    0.9721       456
#                       TERRITORIO     0.9669    0.8984    0.9314      1171
#
#                        micro avg     0.9647    0.9236    0.9437     12180
#                        macro avg     0.7679    0.7269    0.7273     12180
#                     weighted avg     0.9640    0.9236    0.9349     12180
#
# Generating plots for the train set
# Generating plots for the valid set
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/001_train.txt > ./output/_2019-05-15_14-01-31-113906/001_train.txt_conll_evaluation.txt
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/001_valid.txt > ./output/_2019-05-15_14-01-31-113906/001_valid.txt_conll_evaluation.txt
# Formatting 001_train set from CONLL to BRAT... Done.
# Formatting 001_valid set from CONLL to BRAT... Done.
# The last 0 epochs have not shown improvements on the validation set.
#
# Starting epoch 2
# Training completed in 1177.56 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9896    0.9933    0.9914      5545
#                     CENTRO_SALUD     1.0000    0.6552    0.7917        29
#               CORREO_ELECTRONICO     0.9916    0.9937    0.9926       474
#           EDAD_SUJETO_ASISTENCIA     0.9784    0.9841    0.9812      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.8994    0.8324    0.8646       376
#                           FECHAS     0.9888    0.9888    0.9888      1514
#                         HOSPITAL     0.9808    0.9736    0.9772      1100
#                 ID_ASEGURAMIENTO     0.9974    0.9966    0.9970      1160
#          ID_CONTACTO_ASISTENCIAL     0.7476    1.0000    0.8556        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9981    0.8683    0.9287       600
# ID_TITULACION_PERSONAL_SANITARIO     0.9964    1.0000    0.9982      1398
#                      INSTITUCION     0.8843    0.7406    0.8061       320
#        NOMBRE_PERSONAL_SANITARIO     0.9976    0.9991    0.9984      3365
#         NOMBRE_SUJETO_ASISTENCIA     0.9962    0.9981    0.9971      1561
#                       NUMERO_FAX     0.8049    0.7333    0.7674        45
#                  NUMERO_TELEFONO     0.8627    0.9706    0.9135       136
#          OTROS_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000        32
#                             PAIS     0.9830    0.9508    0.9666       731
#                        PROFESION     0.1903    0.8269    0.3094        52
#           SEXO_SUJETO_ASISTENCIA     0.9829    0.9946    0.9887       927
#                       TERRITORIO     0.9767    0.9729    0.9748      2107
#
#                        micro avg     0.9768    0.9780    0.9774     23618
#                        macro avg     0.8294    0.8397    0.8222     23618
#                     weighted avg     0.9813    0.9780    0.9789     23618
#
# Evaluate model on the valid set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9644    0.9828    0.9735      2786
#                     CENTRO_SALUD     0.0000    0.0000    0.0000        11
#               CORREO_ELECTRONICO     0.9795    0.9755    0.9775       245
#           EDAD_SUJETO_ASISTENCIA     0.9831    0.9573    0.9700      1030
#     FAMILIARES_SUJETO_ASISTENCIA     0.7264    0.6016    0.6581       128
#                           FECHAS     0.9458    0.9641    0.9548      1085
#                         HOSPITAL     0.9401    0.9175    0.9287       582
#                 ID_ASEGURAMIENTO     0.9965    0.9726    0.9844       584
#          ID_CONTACTO_ASISTENCIAL     0.5614    1.0000    0.7191        32
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         5
#             ID_SUJETO_ASISTENCIA     0.9962    0.8717    0.9298       304
# ID_TITULACION_PERSONAL_SANITARIO     0.9822    0.9985    0.9903       664
#                      INSTITUCION     0.7263    0.5159    0.6032       252
#        NOMBRE_PERSONAL_SANITARIO     0.9706    0.9894    0.9799      1602
#         NOMBRE_SUJETO_ASISTENCIA     0.9936    0.9962    0.9949       782
#                       NUMERO_FAX     0.0000    0.0000    0.0000        15
#                  NUMERO_TELEFONO     0.7386    0.9028    0.8125        72
#          OTROS_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000        16
#                             PAIS     0.9940    0.9570    0.9752       349
#                        PROFESION     0.0126    0.3333    0.0243         9
#           SEXO_SUJETO_ASISTENCIA     0.9720    0.9912    0.9815       456
#                       TERRITORIO     0.9429    0.9026    0.9223      1171
#
#                        micro avg     0.9402    0.9485    0.9443     12180
#                        macro avg     0.7012    0.7195    0.6991     12180
#                     weighted avg     0.9543    0.9485    0.9504     12180
#
# Generating plots for the train set
# Generating plots for the valid set
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/002_train.txt > ./output/_2019-05-15_14-01-31-113906/002_train.txt_conll_evaluation.txt
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/002_valid.txt > ./output/_2019-05-15_14-01-31-113906/002_valid.txt_conll_evaluation.txt
# Formatting 002_train set from CONLL to BRAT... Done.
# Formatting 002_valid set from CONLL to BRAT... Done.
# The last 0 epochs have not shown improvements on the validation set.
#
# Starting epoch 3
# Training completed in 1190.17 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9962    0.9912    0.9937      5545
#                     CENTRO_SALUD     1.0000    0.0345    0.0667        29
#               CORREO_ELECTRONICO     0.9895    0.9937    0.9916       474
#           EDAD_SUJETO_ASISTENCIA     0.9828    0.9952    0.9890      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.9044    0.8803    0.8922       376
#                           FECHAS     0.9811    0.9934    0.9872      1514
#                         HOSPITAL     0.9800    0.9818    0.9809      1100
#                 ID_ASEGURAMIENTO     0.9974    0.9966    0.9970      1160
#          ID_CONTACTO_ASISTENCIAL     0.9744    0.9870    0.9806        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9726    0.9467    0.9595       600
# ID_TITULACION_PERSONAL_SANITARIO     0.9971    1.0000    0.9986      1398
#                      INSTITUCION     0.8804    0.8281    0.8535       320
#        NOMBRE_PERSONAL_SANITARIO     0.9985    0.9991    0.9988      3365
#         NOMBRE_SUJETO_ASISTENCIA     0.9974    1.0000    0.9987      1561
#                       NUMERO_FAX     0.8000    0.9778    0.8800        45
#                  NUMERO_TELEFONO     1.0000    0.7721    0.8714       136
#          OTROS_SUJETO_ASISTENCIA     1.0000    0.0312    0.0606        32
#                             PAIS     0.9957    0.9535    0.9741       731
#                        PROFESION     0.8246    0.9038    0.8624        52
#           SEXO_SUJETO_ASISTENCIA     0.9914    0.9935    0.9925       927
#                       TERRITORIO     0.9762    0.9915    0.9838      2107
#
#                        micro avg     0.9872    0.9837    0.9854     23618
#                        macro avg     0.9200    0.8296    0.8324     23618
#                     weighted avg     0.9873    0.9837    0.9842     23618
#
# Evaluate model on the valid set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9891    0.9788    0.9839      2786
#                     CENTRO_SALUD     0.0000    0.0000    0.0000        11
#               CORREO_ELECTRONICO     0.9796    0.9796    0.9796       245
#           EDAD_SUJETO_ASISTENCIA     0.9748    0.9777    0.9762      1030
#     FAMILIARES_SUJETO_ASISTENCIA     0.7311    0.6797    0.7045       128
#                           FECHAS     0.9678    0.9419    0.9547      1085
#                         HOSPITAL     0.9228    0.9244    0.9236       582
#                 ID_ASEGURAMIENTO     0.9948    0.9743    0.9844       584
#          ID_CONTACTO_ASISTENCIAL     0.9667    0.9062    0.9355        32
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         5
#             ID_SUJETO_ASISTENCIA     0.9452    0.9079    0.9262       304
# ID_TITULACION_PERSONAL_SANITARIO     0.9822    0.9985    0.9903       664
#                      INSTITUCION     0.7519    0.3968    0.5195       252
#        NOMBRE_PERSONAL_SANITARIO     0.9629    0.9875    0.9750      1602
#         NOMBRE_SUJETO_ASISTENCIA     0.9949    0.9949    0.9949       782
#                       NUMERO_FAX     0.5000    0.8000    0.6154        15
#                  NUMERO_TELEFONO     0.9298    0.7361    0.8217        72
#          OTROS_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000        16
#                             PAIS     1.0000    0.9398    0.9690       349
#                        PROFESION     0.0000    0.0000    0.0000         9
#           SEXO_SUJETO_ASISTENCIA     0.9826    0.9912    0.9869       456
#                       TERRITORIO     0.9422    0.9462    0.9442      1171
#
#                        micro avg     0.9658    0.9500    0.9578     12180
#                        macro avg     0.7508    0.7301    0.7357     12180
#                     weighted avg     0.9620    0.9500    0.9546     12180
#
# Generating plots for the train set
# Generating plots for the valid set
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/003_train.txt > ./output/_2019-05-15_14-01-31-113906/003_train.txt_conll_evaluation.txt
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/003_valid.txt > ./output/_2019-05-15_14-01-31-113906/003_valid.txt_conll_evaluation.txt
# Formatting 003_train set from CONLL to BRAT... Done.
# Formatting 003_valid set from CONLL to BRAT... Done.
# The last 0 epochs have not shown improvements on the validation set.
#
# Starting epoch 4
# Training completed in 1089.71 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9975    0.9973    0.9974      5545
#                     CENTRO_SALUD     1.0000    0.8621    0.9259        29
#               CORREO_ELECTRONICO     0.9958    0.9895    0.9926       474
#           EDAD_SUJETO_ASISTENCIA     0.9893    0.9845    0.9869      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.9763    0.8750    0.9229       376
#                           FECHAS     0.9993    0.9881    0.9937      1514
#                         HOSPITAL     0.9819    0.9855    0.9837      1100
#                 ID_ASEGURAMIENTO     0.9974    0.9966    0.9970      1160
#          ID_CONTACTO_ASISTENCIAL     0.9747    1.0000    0.9872        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9827    0.9483    0.9652       600
# ID_TITULACION_PERSONAL_SANITARIO     0.9979    1.0000    0.9989      1398
#                      INSTITUCION     0.9871    0.7188    0.8318       320
#        NOMBRE_PERSONAL_SANITARIO     0.9991    0.9988    0.9990      3365
#         NOMBRE_SUJETO_ASISTENCIA     1.0000    0.9981    0.9990      1561
#                       NUMERO_FAX     0.8163    0.8889    0.8511        45
#                  NUMERO_TELEFONO     0.9237    0.8897    0.9064       136
#          OTROS_SUJETO_ASISTENCIA     1.0000    0.1562    0.2703        32
#                             PAIS     0.9917    0.9795    0.9855       731
#                        PROFESION     0.5432    0.8462    0.6617        52
#           SEXO_SUJETO_ASISTENCIA     0.9968    0.9935    0.9951       927
#                       TERRITORIO     0.9676    0.9934    0.9803      2107
#
#                        micro avg     0.9904    0.9848    0.9876     23618
#                        macro avg     0.9145    0.8677    0.8742     23618
#                     weighted avg     0.9910    0.9848    0.9870     23618
#
# Evaluate model on the valid set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9901    0.9709    0.9804      2786
#                     CENTRO_SALUD     1.0000    0.6364    0.7778        11
#               CORREO_ELECTRONICO     0.9957    0.9469    0.9707       245
#           EDAD_SUJETO_ASISTENCIA     0.9939    0.9447    0.9686      1030
#     FAMILIARES_SUJETO_ASISTENCIA     0.7857    0.6016    0.6814       128
#                           FECHAS     0.9937    0.8774    0.9320      1085
#                         HOSPITAL     0.9168    0.9467    0.9315       582
#                 ID_ASEGURAMIENTO     0.9982    0.9743    0.9861       584
#          ID_CONTACTO_ASISTENCIAL     0.9697    1.0000    0.9846        32
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         5
#             ID_SUJETO_ASISTENCIA     0.9647    0.8980    0.9302       304
# ID_TITULACION_PERSONAL_SANITARIO     0.9822    0.9985    0.9903       664
#                      INSTITUCION     0.7899    0.3730    0.5067       252
#        NOMBRE_PERSONAL_SANITARIO     0.9846    0.9594    0.9719      1602
#         NOMBRE_SUJETO_ASISTENCIA     0.9974    0.9949    0.9962       782
#                       NUMERO_FAX     0.9000    0.6000    0.7200        15
#                  NUMERO_TELEFONO     0.8250    0.9167    0.8684        72
#          OTROS_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000        16
#                             PAIS     0.9941    0.9628    0.9782       349
#                        PROFESION     0.0000    0.0000    0.0000         9
#           SEXO_SUJETO_ASISTENCIA     0.9933    0.9825    0.9879       456
#                       TERRITORIO     0.9262    0.9539    0.9398      1171
#
#                        micro avg     0.9731    0.9375    0.9550     12180
#                        macro avg     0.8182    0.7518    0.7774     12180
#                     weighted avg     0.9707    0.9375    0.9518     12180
#
# Generating plots for the train set
# Generating plots for the valid set
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/004_train.txt > ./output/_2019-05-15_14-01-31-113906/004_train.txt_conll_evaluation.txt
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/004_valid.txt > ./output/_2019-05-15_14-01-31-113906/004_valid.txt_conll_evaluation.txt
# The last 1 epochs have not shown improvements on the validation set.
#
# Starting epoch 5
# Training completed in 714.54 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9955    0.9993    0.9974      5545
#                     CENTRO_SALUD     1.0000    0.9655    0.9825        29
#               CORREO_ELECTRONICO     0.9958    0.9958    0.9958       474
#           EDAD_SUJETO_ASISTENCIA     0.9909    0.9957    0.9932      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.9601    0.9601    0.9601       376
#                           FECHAS     0.9967    0.9941    0.9954      1514
#                         HOSPITAL     0.9936    0.9836    0.9886      1100
#                 ID_ASEGURAMIENTO     0.9983    0.9966    0.9974      1160
#          ID_CONTACTO_ASISTENCIAL     0.9747    1.0000    0.9872        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9882    0.9750    0.9815       600
# ID_TITULACION_PERSONAL_SANITARIO     0.9979    1.0000    0.9989      1398
#                      INSTITUCION     0.9635    0.8250    0.8889       320
#        NOMBRE_PERSONAL_SANITARIO     1.0000    0.9988    0.9994      3365
#         NOMBRE_SUJETO_ASISTENCIA     0.9994    1.0000    0.9997      1561
#                       NUMERO_FAX     1.0000    0.9778    0.9888        45
#                  NUMERO_TELEFONO     0.9852    0.9779    0.9815       136
#          OTROS_SUJETO_ASISTENCIA     0.8462    0.6875    0.7586        32
#                             PAIS     0.9945    0.9822    0.9883       731
#                        PROFESION     0.9714    0.6538    0.7816        52
#           SEXO_SUJETO_ASISTENCIA     0.9925    0.9968    0.9946       927
#                       TERRITORIO     0.9822    0.9948    0.9884      2107
#
#                        micro avg     0.9935    0.9917    0.9926     23618
#                        macro avg     0.9376    0.9073    0.9204     23618
#                     weighted avg     0.9934    0.9917    0.9924     23618
#
# Evaluate model on the valid set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9618    0.9842    0.9729      2786
#                     CENTRO_SALUD     1.0000    0.5455    0.7059        11
#               CORREO_ELECTRONICO     0.9917    0.9755    0.9835       245
#           EDAD_SUJETO_ASISTENCIA     0.9872    0.9748    0.9809      1030
#     FAMILIARES_SUJETO_ASISTENCIA     0.7304    0.6562    0.6914       128
#                           FECHAS     0.9910    0.9088    0.9481      1085
#                         HOSPITAL     0.9766    0.9313    0.9534       582
#                 ID_ASEGURAMIENTO     1.0000    0.9709    0.9852       584
#          ID_CONTACTO_ASISTENCIAL     0.9697    1.0000    0.9846        32
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         5
#             ID_SUJETO_ASISTENCIA     0.9514    0.9013    0.9257       304
# ID_TITULACION_PERSONAL_SANITARIO     0.9822    0.9985    0.9903       664
#                      INSTITUCION     0.6845    0.5079    0.5831       252
#        NOMBRE_PERSONAL_SANITARIO     0.9936    0.9632    0.9781      1602
#         NOMBRE_SUJETO_ASISTENCIA     0.9974    0.9962    0.9968       782
#                       NUMERO_FAX     1.0000    0.5333    0.6957        15
#                  NUMERO_TELEFONO     0.9103    0.9861    0.9467        72
#          OTROS_SUJETO_ASISTENCIA     0.2500    0.1250    0.1667        16
#                             PAIS     0.9941    0.9628    0.9782       349
#                        PROFESION     0.2500    0.1111    0.1538         9
#           SEXO_SUJETO_ASISTENCIA     0.9638    0.9912    0.9773       456
#                       TERRITORIO     0.9235    0.9479    0.9355      1171
#
#                        micro avg     0.9664    0.9498    0.9581     12180
#                        macro avg     0.8413    0.7714    0.7970     12180
#                     weighted avg     0.9641    0.9498    0.9562     12180
#
# Generating plots for the train set
# Generating plots for the valid set
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/005_train.txt > ./output/_2019-05-15_14-01-31-113906/005_train.txt_conll_evaluation.txt
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/005_valid.txt > ./output/_2019-05-15_14-01-31-113906/005_valid.txt_conll_evaluation.txt
# Formatting 005_train set from CONLL to BRAT... Done.
# Formatting 005_valid set from CONLL to BRAT... Done.
# The last 0 epochs have not shown improvements on the validation set.
#
# Starting epoch 6
# Training completed in 714.43 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9960    0.9984    0.9972      5545
#                     CENTRO_SALUD     0.7436    1.0000    0.8529        29
#               CORREO_ELECTRONICO     0.9895    0.9958    0.9926       474
#           EDAD_SUJETO_ASISTENCIA     0.9948    0.9275    0.9600      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.9942    0.9149    0.9529       376
#                           FECHAS     0.9947    0.9954    0.9950      1514
#                         HOSPITAL     0.9991    0.9736    0.9862      1100
#                 ID_ASEGURAMIENTO     0.9991    0.9966    0.9978      1160
#          ID_CONTACTO_ASISTENCIAL     0.9861    0.9221    0.9530        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9660    0.9950    0.9803       600
# ID_TITULACION_PERSONAL_SANITARIO     0.9979    1.0000    0.9989      1398
#                      INSTITUCION     0.9739    0.8156    0.8878       320
#        NOMBRE_PERSONAL_SANITARIO     0.9959    0.9994    0.9976      3365
#         NOMBRE_SUJETO_ASISTENCIA     0.9987    1.0000    0.9994      1561
#                       NUMERO_FAX     0.9778    0.9778    0.9778        45
#                  NUMERO_TELEFONO     0.9781    0.9853    0.9817       136
#          OTROS_SUJETO_ASISTENCIA     1.0000    0.7188    0.8364        32
#                             PAIS     0.9972    0.9590    0.9777       731
#                        PROFESION     0.9792    0.9038    0.9400        52
#           SEXO_SUJETO_ASISTENCIA     0.9978    0.9968    0.9973       927
#                       TERRITORIO     0.9823    0.9986    0.9904      2107
#
#                        micro avg     0.9934    0.9849    0.9892     23618
#                        macro avg     0.9337    0.9125    0.9206     23618
#                     weighted avg     0.9935    0.9849    0.9889     23618
#
# Evaluate model on the valid set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9838    0.9788    0.9813      2786
#                     CENTRO_SALUD     0.2895    1.0000    0.4490        11
#               CORREO_ELECTRONICO     1.0000    0.9429    0.9706       245
#           EDAD_SUJETO_ASISTENCIA     0.9956    0.8874    0.9384      1030
#     FAMILIARES_SUJETO_ASISTENCIA     0.7699    0.6797    0.7220       128
#                           FECHAS     0.9823    0.9226    0.9515      1085
#                         HOSPITAL     0.9453    0.9210    0.9330       582
#                 ID_ASEGURAMIENTO     0.9965    0.9726    0.9844       584
#          ID_CONTACTO_ASISTENCIAL     1.0000    0.8750    0.9333        32
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         5
#             ID_SUJETO_ASISTENCIA     0.9032    0.9211    0.9121       304
# ID_TITULACION_PERSONAL_SANITARIO     0.9822    0.9985    0.9903       664
#                      INSTITUCION     0.8425    0.4246    0.5646       252
#        NOMBRE_PERSONAL_SANITARIO     0.9776    0.9819    0.9798      1602
#         NOMBRE_SUJETO_ASISTENCIA     0.9848    0.9962    0.9905       782
#                       NUMERO_FAX     0.6500    0.8667    0.7429        15
#                  NUMERO_TELEFONO     0.9452    0.9583    0.9517        72
#          OTROS_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000        16
#                             PAIS     1.0000    0.9398    0.9690       349
#                        PROFESION     0.0000    0.0000    0.0000         9
#           SEXO_SUJETO_ASISTENCIA     0.9784    0.9912    0.9847       456
#                       TERRITORIO     0.9397    0.9590    0.9493      1171
#
#                        micro avg     0.9683    0.9433    0.9557     12180
#                        macro avg     0.7803    0.7826    0.7681     12180
#                     weighted avg     0.9681    0.9433    0.9536     12180
#
# Generating plots for the train set
# Generating plots for the valid set
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/006_train.txt > ./output/_2019-05-15_14-01-31-113906/006_train.txt_conll_evaluation.txt
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/006_valid.txt > ./output/_2019-05-15_14-01-31-113906/006_valid.txt_conll_evaluation.txt
# The last 1 epochs have not shown improvements on the validation set.
#
# Starting epoch 7
# Training completed in 714.31 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9973    0.9982    0.9977      5545
#                     CENTRO_SALUD     1.0000    1.0000    1.0000        29
#               CORREO_ELECTRONICO     1.0000    0.9705    0.9850       474
#           EDAD_SUJETO_ASISTENCIA     0.9937    0.9952    0.9944      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.9842    0.9947    0.9894       376
#                           FECHAS     0.9934    0.9941    0.9937      1514
#                         HOSPITAL     0.9741    0.9927    0.9833      1100
#                 ID_ASEGURAMIENTO     0.9974    0.9991    0.9983      1160
#          ID_CONTACTO_ASISTENCIAL     0.9747    1.0000    0.9872        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9933    0.9917    0.9925       600
# ID_TITULACION_PERSONAL_SANITARIO     1.0000    0.9986    0.9993      1398
#                      INSTITUCION     0.9862    0.8938    0.9377       320
#        NOMBRE_PERSONAL_SANITARIO     1.0000    0.9979    0.9990      3365
#         NOMBRE_SUJETO_ASISTENCIA     1.0000    1.0000    1.0000      1561
#                       NUMERO_FAX     1.0000    0.7333    0.8462        45
#                  NUMERO_TELEFONO     0.9007    1.0000    0.9477       136
#          OTROS_SUJETO_ASISTENCIA     1.0000    0.6562    0.7925        32
#                             PAIS     0.9863    0.9877    0.9870       731
#                        PROFESION     1.0000    0.5769    0.7317        52
#           SEXO_SUJETO_ASISTENCIA     0.9946    0.9978    0.9962       927
#                       TERRITORIO     0.9981    0.9962    0.9971      2107
#
#                        micro avg     0.9949    0.9930    0.9939     23618
#                        macro avg     0.9443    0.8988    0.9162     23618
#                     weighted avg     0.9950    0.9930    0.9937     23618
#
# Evaluate model on the valid set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9726    0.9828    0.9777      2786
#                     CENTRO_SALUD     1.0000    0.7273    0.8421        11
#               CORREO_ELECTRONICO     1.0000    0.9184    0.9574       245
#           EDAD_SUJETO_ASISTENCIA     0.9832    0.9641    0.9735      1030
#     FAMILIARES_SUJETO_ASISTENCIA     0.7934    0.7500    0.7711       128
#                           FECHAS     0.9705    0.9392    0.9546      1085
#                         HOSPITAL     0.8629    0.9622    0.9098       582
#                 ID_ASEGURAMIENTO     0.9793    0.9743    0.9768       584
#          ID_CONTACTO_ASISTENCIAL     0.8889    1.0000    0.9412        32
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         5
#             ID_SUJETO_ASISTENCIA     0.9720    0.9145    0.9424       304
# ID_TITULACION_PERSONAL_SANITARIO     0.9819    0.9804    0.9812       664
#                      INSTITUCION     0.7626    0.4206    0.5422       252
#        NOMBRE_PERSONAL_SANITARIO     0.9812    0.9126    0.9457      1602
#         NOMBRE_SUJETO_ASISTENCIA     0.9936    0.9949    0.9942       782
#                       NUMERO_FAX     1.0000    0.2000    0.3333        15
#                  NUMERO_TELEFONO     0.7831    0.9028    0.8387        72
#          OTROS_SUJETO_ASISTENCIA     0.5000    0.1250    0.2000        16
#                             PAIS     0.9631    0.9713    0.9672       349
#                        PROFESION     0.0000    0.0000    0.0000         9
#           SEXO_SUJETO_ASISTENCIA     0.9826    0.9912    0.9869       456
#                       TERRITORIO     0.9731    0.9283    0.9502      1171
#
#                        micro avg     0.9653    0.9411    0.9531     12180
#                        macro avg     0.8338    0.7527    0.7721     12180
#                     weighted avg     0.9628    0.9411    0.9500     12180
#
# Generating plots for the train set
# Generating plots for the valid set
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/007_train.txt > ./output/_2019-05-15_14-01-31-113906/007_train.txt_conll_evaluation.txt
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/007_valid.txt > ./output/_2019-05-15_14-01-31-113906/007_valid.txt_conll_evaluation.txt
# The last 2 epochs have not shown improvements on the validation set.
#
# Starting epoch 8
# Training completed in 714.60 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9937    0.9982    0.9960      5545
#                     CENTRO_SALUD     1.0000    0.9655    0.9825        29
#               CORREO_ELECTRONICO     0.9958    0.9958    0.9958       474
#           EDAD_SUJETO_ASISTENCIA     0.9971    0.9937    0.9954      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.9816    0.9920    0.9868       376
#                           FECHAS     0.9960    0.9934    0.9947      1514
#                         HOSPITAL     0.9982    0.9909    0.9945      1100
#                 ID_ASEGURAMIENTO     0.9974    0.9991    0.9983      1160
#          ID_CONTACTO_ASISTENCIAL     0.9747    1.0000    0.9872        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9932    0.9800    0.9866       600
# ID_TITULACION_PERSONAL_SANITARIO     1.0000    1.0000    1.0000      1398
#                      INSTITUCION     0.9650    0.9469    0.9558       320
#        NOMBRE_PERSONAL_SANITARIO     1.0000    0.9991    0.9996      3365
#         NOMBRE_SUJETO_ASISTENCIA     1.0000    1.0000    1.0000      1561
#                       NUMERO_FAX     0.9362    0.9778    0.9565        45
#                  NUMERO_TELEFONO     0.9778    0.9706    0.9742       136
#          OTROS_SUJETO_ASISTENCIA     0.8929    0.7812    0.8333        32
#                             PAIS     0.9784    0.9918    0.9851       731
#                        PROFESION     1.0000    0.8077    0.8936        52
#           SEXO_SUJETO_ASISTENCIA     0.9957    0.9957    0.9957       927
#                       TERRITORIO     0.9896    0.9924    0.9910      2107
#
#                        micro avg     0.9945    0.9945    0.9945     23618
#                        macro avg     0.9392    0.9260    0.9319     23618
#                     weighted avg     0.9945    0.9945    0.9945     23618
#
# Evaluate model on the valid set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9397    0.9795    0.9592      2786
#                     CENTRO_SALUD     0.8571    0.5455    0.6667        11
#               CORREO_ELECTRONICO     0.9796    0.9796    0.9796       245
#           EDAD_SUJETO_ASISTENCIA     0.9900    0.9573    0.9733      1030
#     FAMILIARES_SUJETO_ASISTENCIA     0.7542    0.6953    0.7236       128
#                           FECHAS     0.9928    0.8894    0.9383      1085
#                         HOSPITAL     0.9539    0.9244    0.9389       582
#                 ID_ASEGURAMIENTO     0.9827    0.9743    0.9785       584
#          ID_CONTACTO_ASISTENCIAL     0.9697    1.0000    0.9846        32
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         5
#             ID_SUJETO_ASISTENCIA     0.9824    0.9178    0.9490       304
# ID_TITULACION_PERSONAL_SANITARIO     0.9821    0.9940    0.9880       664
#                      INSTITUCION     0.6748    0.5516    0.6070       252
#        NOMBRE_PERSONAL_SANITARIO     0.9693    0.9663    0.9678      1602
#         NOMBRE_SUJETO_ASISTENCIA     0.9974    0.9910    0.9942       782
#                       NUMERO_FAX     0.5714    0.8000    0.6667        15
#                  NUMERO_TELEFONO     1.0000    0.8472    0.9173        72
#          OTROS_SUJETO_ASISTENCIA     0.2500    0.1250    0.1667        16
#                             PAIS     0.9738    0.9599    0.9668       349
#                        PROFESION     0.0000    0.0000    0.0000         9
#           SEXO_SUJETO_ASISTENCIA     0.9782    0.9825    0.9803       456
#                       TERRITORIO     0.9358    0.9206    0.9281      1171
#
#                        micro avg     0.9573    0.9434    0.9503     12180
#                        macro avg     0.8061    0.7728    0.7852     12180
#                     weighted avg     0.9557    0.9434    0.9489     12180
#
# Generating plots for the train set
# Generating plots for the valid set
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/008_train.txt > ./output/_2019-05-15_14-01-31-113906/008_train.txt_conll_evaluation.txt
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/008_valid.txt > ./output/_2019-05-15_14-01-31-113906/008_valid.txt_conll_evaluation.txt
# The last 3 epochs have not shown improvements on the validation set.
#
# Starting epoch 9
# Training completed in 714.75 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9984    0.9986    0.9985      5545
#                     CENTRO_SALUD     1.0000    1.0000    1.0000        29
#               CORREO_ELECTRONICO     0.5287    0.9916    0.6897       474
#           EDAD_SUJETO_ASISTENCIA     0.9876    1.0000    0.9938      2069
#     FAMILIARES_SUJETO_ASISTENCIA     1.0000    0.9867    0.9933       376
#                           FECHAS     0.9672    0.9947    0.9808      1514
#                         HOSPITAL     0.9847    0.9918    0.9882      1100
#                 ID_ASEGURAMIENTO     0.9991    0.9991    0.9991      1160
#          ID_CONTACTO_ASISTENCIAL     0.9747    1.0000    0.9872        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9950    0.9917    0.9933       600
# ID_TITULACION_PERSONAL_SANITARIO     1.0000    1.0000    1.0000      1398
#                      INSTITUCION     0.9869    0.9406    0.9632       320
#        NOMBRE_PERSONAL_SANITARIO     0.9976    1.0000    0.9988      3365
#         NOMBRE_SUJETO_ASISTENCIA     1.0000    1.0000    1.0000      1561
#                       NUMERO_FAX     0.8824    1.0000    0.9375        45
#                  NUMERO_TELEFONO     0.9747    0.5662    0.7163       136
#          OTROS_SUJETO_ASISTENCIA     1.0000    0.7812    0.8772        32
#                             PAIS     0.9891    0.9891    0.9891       731
#                        PROFESION     1.0000    0.8462    0.9167        52
#           SEXO_SUJETO_ASISTENCIA     0.9946    1.0000    0.9973       927
#                       TERRITORIO     0.9986    0.9962    0.9974      2107
#
#                        micro avg     0.9765    0.9937    0.9850     23618
#                        macro avg     0.9209    0.9124    0.9099     23618
#                     weighted avg     0.9844    0.9937    0.9873     23618
#
# Evaluate model on the valid set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9674    0.9810    0.9742      2786
#                     CENTRO_SALUD     0.8889    0.7273    0.8000        11
#               CORREO_ELECTRONICO     0.4702    0.9673    0.6328       245
#           EDAD_SUJETO_ASISTENCIA     0.9546    0.9806    0.9674      1030
#     FAMILIARES_SUJETO_ASISTENCIA     0.7018    0.6250    0.6612       128
#                           FECHAS     0.9521    0.9152    0.9333      1085
#                         HOSPITAL     0.9515    0.9433    0.9474       582
#                 ID_ASEGURAMIENTO     0.9948    0.9743    0.9844       584
#          ID_CONTACTO_ASISTENCIAL     0.9697    1.0000    0.9846        32
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         5
#             ID_SUJETO_ASISTENCIA     0.9580    0.9013    0.9288       304
# ID_TITULACION_PERSONAL_SANITARIO     0.9821    0.9940    0.9880       664
#                      INSTITUCION     0.7447    0.5556    0.6364       252
#        NOMBRE_PERSONAL_SANITARIO     0.9712    0.9694    0.9703      1602
#         NOMBRE_SUJETO_ASISTENCIA     0.9974    0.9949    0.9962       782
#                       NUMERO_FAX     0.5500    0.7333    0.6286        15
#                  NUMERO_TELEFONO     0.9545    0.2917    0.4468        72
#          OTROS_SUJETO_ASISTENCIA     0.0000    0.0000    0.0000        16
#                             PAIS     0.9744    0.9828    0.9786       349
#                        PROFESION     0.0000    0.0000    0.0000         9
#           SEXO_SUJETO_ASISTENCIA     0.9617    0.9912    0.9762       456
#                       TERRITORIO     0.9845    0.9214    0.9519      1171
#
#                        micro avg     0.9423    0.9460    0.9442     12180
#                        macro avg     0.7695    0.7477    0.7449     12180
#                     weighted avg     0.9497    0.9460    0.9445     12180
#
# Generating plots for the train set
# Generating plots for the valid set
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/009_train.txt > ./output/_2019-05-15_14-01-31-113906/009_train.txt_conll_evaluation.txt
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/009_valid.txt > ./output/_2019-05-15_14-01-31-113906/009_valid.txt_conll_evaluation.txt
# The last 4 epochs have not shown improvements on the validation set.
#
# Starting epoch 10
# Training completed in 829.10 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9978    0.9973    0.9976      5545
#                     CENTRO_SALUD     1.0000    1.0000    1.0000        29
#               CORREO_ELECTRONICO     0.9958    0.9937    0.9947       474
#           EDAD_SUJETO_ASISTENCIA     0.9961    0.9995    0.9978      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.9867    0.9840    0.9854       376
#                           FECHAS     0.9973    0.9941    0.9957      1514
#                         HOSPITAL     0.9830    1.0000    0.9914      1100
#                 ID_ASEGURAMIENTO     0.9991    0.9991    0.9991      1160
#          ID_CONTACTO_ASISTENCIAL     0.9747    1.0000    0.9872        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9950    0.9950    0.9950       600
# ID_TITULACION_PERSONAL_SANITARIO     1.0000    1.0000    1.0000      1398
#                      INSTITUCION     0.9273    0.9969    0.9608       320
#        NOMBRE_PERSONAL_SANITARIO     0.9988    1.0000    0.9994      3365
#         NOMBRE_SUJETO_ASISTENCIA     1.0000    1.0000    1.0000      1561
# ...
# The last 44 epochs have not shown improvements on the validation set.
#
# Starting epoch 58
# Training completed in 963.42 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9969    0.9975    0.9972      5545
#                     CENTRO_SALUD     1.0000    1.0000    1.0000        29
#               CORREO_ELECTRONICO     0.9958    0.9916    0.9937       474
#           EDAD_SUJETO_ASISTENCIA     0.9971    0.9961    0.9966      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.9588    0.9894    0.9738       376
#                           FECHAS     0.9908    0.9941    0.9924      1514
#                         HOSPITAL     0.9855    0.9873    0.9864      1100
#                 ID_ASEGURAMIENTO     0.9957    0.9966    0.9961      1160
#          ID_CONTACTO_ASISTENCIAL     0.9747    1.0000    0.9872        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9916    0.9883    0.9900       600
# ID_TITULACION_PERSONAL_SANITARIO     0.9979    1.0000    0.9989      1398
#                      INSTITUCION     0.9741    0.9406    0.9571       320
#        NOMBRE_PERSONAL_SANITARIO     0.9982    0.9997    0.9990      3365
#         NOMBRE_SUJETO_ASISTENCIA     0.9987    0.9981    0.9984      1561
#                       NUMERO_FAX     0.8824    1.0000    0.9375        45
#                  NUMERO_TELEFONO     0.9028    0.9559    0.9286       136
#          OTROS_SUJETO_ASISTENCIA     1.0000    0.5938    0.7451        32
#                             PAIS     0.9863    0.9850    0.9856       731
#                        PROFESION     1.0000    0.8846    0.9388        52
#           SEXO_SUJETO_ASISTENCIA     0.9946    0.9968    0.9957       927
#                       TERRITORIO     0.9868    0.9924    0.9896      2107
#
#                        micro avg     0.9930    0.9940    0.9935     23618
#                        macro avg     0.9368    0.9222    0.9267     23618
#                     weighted avg     0.9931    0.9940    0.9934     23618
#
# Evaluate model on the valid set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9491    0.9774    0.9630      2786
#                     CENTRO_SALUD     0.8333    0.9091    0.8696        11
#               CORREO_ELECTRONICO     0.9708    0.9510    0.9608       245
#           EDAD_SUJETO_ASISTENCIA     0.9850    0.9534    0.9689      1030
#     FAMILIARES_SUJETO_ASISTENCIA     0.5949    0.7344    0.6573       128
#                           FECHAS     0.9573    0.9097    0.9329      1085
#                         HOSPITAL     0.9693    0.9210    0.9445       582
#                 ID_ASEGURAMIENTO     0.9693    0.9743    0.9718       584
#          ID_CONTACTO_ASISTENCIAL     0.9697    1.0000    0.9846        32
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         5
#             ID_SUJETO_ASISTENCIA     0.9582    0.9046    0.9306       304
# ID_TITULACION_PERSONAL_SANITARIO     0.9458    0.9985    0.9714       664
#                      INSTITUCION     0.7079    0.5675    0.6300       252
#        NOMBRE_PERSONAL_SANITARIO     0.9624    0.9270    0.9444      1602
#         NOMBRE_SUJETO_ASISTENCIA     0.9936    0.9923    0.9930       782
#                       NUMERO_FAX     0.2727    0.6000    0.3750        15
#                  NUMERO_TELEFONO     0.6286    0.9167    0.7458        72
#          OTROS_SUJETO_ASISTENCIA     0.2857    0.1250    0.1739        16
#                             PAIS     0.9970    0.9656    0.9811       349
#                        PROFESION     0.0000    0.0000    0.0000         9
#           SEXO_SUJETO_ASISTENCIA     0.9869    0.9890    0.9880       456
#                       TERRITORIO     0.9376    0.9368    0.9372      1171
#
#                        micro avg     0.9468    0.9417    0.9442     12180
#                        macro avg     0.7671    0.7842    0.7693     12180
#                     weighted avg     0.9481    0.9417    0.9441     12180
#
# Generating plots for the train set
# Generating plots for the valid set
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/058_train.txt > ./output/_2019-05-15_14-01-31-113906/058_train.txt_conll_evaluation.txt
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/058_valid.txt > ./output/_2019-05-15_14-01-31-113906/058_valid.txt_conll_evaluation.txt
# The last 45 epochs have not shown improvements on the validation set.
#
# Starting epoch 59
# Training completed in 963.89 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9987    0.9946    0.9967      5545
#                     CENTRO_SALUD     1.0000    1.0000    1.0000        29
#               CORREO_ELECTRONICO     0.9874    0.9916    0.9895       474
#           EDAD_SUJETO_ASISTENCIA     0.9890    0.9990    0.9940      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.9688    0.9920    0.9803       376
#                           FECHAS     0.9954    0.9914    0.9934      1514
#                         HOSPITAL     0.9742    0.9964    0.9852      1100
#                 ID_ASEGURAMIENTO     0.9983    0.9991    0.9987      1160
#          ID_CONTACTO_ASISTENCIAL     0.8556    1.0000    0.9222        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9933    0.9867    0.9900       600
# ID_TITULACION_PERSONAL_SANITARIO     1.0000    1.0000    1.0000      1398
#                      INSTITUCION     0.9836    0.9375    0.9600       320
#        NOMBRE_PERSONAL_SANITARIO     1.0000    0.9976    0.9988      3365
#         NOMBRE_SUJETO_ASISTENCIA     0.9987    1.0000    0.9994      1561
#                       NUMERO_FAX     0.9375    1.0000    0.9677        45
#                  NUMERO_TELEFONO     0.9778    0.9706    0.9742       136
#          OTROS_SUJETO_ASISTENCIA     1.0000    0.5312    0.6939        32
#                             PAIS     0.9851    0.9918    0.9884       731
#                        PROFESION     0.8793    0.9808    0.9273        52
#           SEXO_SUJETO_ASISTENCIA     0.9957    1.0000    0.9978       927
#                       TERRITORIO     0.9947    0.9815    0.9881      2107
#
#                        micro avg     0.9937    0.9933    0.9935     23618
#                        macro avg     0.9324    0.9246    0.9248     23618
#                     weighted avg     0.9938    0.9933    0.9934     23618
#
# Evaluate model on the valid set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9716    0.9688    0.9702      2786
#                     CENTRO_SALUD     1.0000    0.9091    0.9524        11
#               CORREO_ELECTRONICO     0.9365    0.9633    0.9497       245
#           EDAD_SUJETO_ASISTENCIA     0.9786    0.9767    0.9776      1030
#     FAMILIARES_SUJETO_ASISTENCIA     0.6777    0.6406    0.6586       128
#                           FECHAS     0.9716    0.9152    0.9426      1085
#                         HOSPITAL     0.8813    0.9570    0.9176       582
#                 ID_ASEGURAMIENTO     0.9861    0.9709    0.9784       584
#          ID_CONTACTO_ASISTENCIAL     0.6957    1.0000    0.8205        32
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         5
#             ID_SUJETO_ASISTENCIA     0.9262    0.9079    0.9169       304
# ID_TITULACION_PERSONAL_SANITARIO     0.9793    0.9985    0.9888       664
#                      INSTITUCION     0.7310    0.4960    0.5910       252
#        NOMBRE_PERSONAL_SANITARIO     0.9623    0.9245    0.9430      1602
#         NOMBRE_SUJETO_ASISTENCIA     0.9701    0.9962    0.9830       782
#                       NUMERO_FAX     0.2632    0.3333    0.2941        15
#                  NUMERO_TELEFONO     0.7000    0.7778    0.7368        72
#          OTROS_SUJETO_ASISTENCIA     0.4000    0.1250    0.1905        16
#                             PAIS     0.9600    0.9628    0.9614       349
#                        PROFESION     0.0000    0.0000    0.0000         9
#           SEXO_SUJETO_ASISTENCIA     0.9740    0.9868    0.9804       456
#                       TERRITORIO     0.9675    0.9146    0.9403      1171
#
#                        micro avg     0.9512    0.9381    0.9446     12180
#                        macro avg     0.7697    0.7602    0.7588     12180
#                     weighted avg     0.9521    0.9381    0.9441     12180
#
# Generating plots for the train set
# Generating plots for the valid set
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/059_train.txt > ./output/_2019-05-15_14-01-31-113906/059_train.txt_conll_evaluation.txt
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/059_valid.txt > ./output/_2019-05-15_14-01-31-113906/059_valid.txt_conll_evaluation.txt
# The last 46 epochs have not shown improvements on the validation set.
#
# Starting epoch 60
# Training completed in 924.94 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9964    0.9982    0.9973      5545
#                     CENTRO_SALUD     1.0000    1.0000    1.0000        29
#               CORREO_ELECTRONICO     0.9958    0.9937    0.9947       474
#           EDAD_SUJETO_ASISTENCIA     0.9829    0.9976    0.9902      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.9738    0.9894    0.9815       376
#                           FECHAS     0.9973    0.9934    0.9954      1514
#                         HOSPITAL     0.9909    0.9855    0.9881      1100
#                 ID_ASEGURAMIENTO     0.9991    0.9966    0.9978      1160
#          ID_CONTACTO_ASISTENCIAL     0.9747    1.0000    0.9872        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9917    0.9950    0.9933       600
# ID_TITULACION_PERSONAL_SANITARIO     0.9979    1.0000    0.9989      1398
#                      INSTITUCION     0.9208    0.9812    0.9501       320
#        NOMBRE_PERSONAL_SANITARIO     0.9994    0.9973    0.9984      3365
#         NOMBRE_SUJETO_ASISTENCIA     1.0000    0.9994    0.9997      1561
#                       NUMERO_FAX     1.0000    0.9333    0.9655        45
#                  NUMERO_TELEFONO     0.9510    1.0000    0.9749       136
#          OTROS_SUJETO_ASISTENCIA     1.0000    0.5625    0.7200        32
#                             PAIS     0.9851    0.9932    0.9891       731
#                        PROFESION     0.9444    0.9808    0.9623        52
#           SEXO_SUJETO_ASISTENCIA     0.9968    1.0000    0.9984       927
#                       TERRITORIO     0.9933    0.9896    0.9914      2107
#
#                        micro avg     0.9932    0.9951    0.9942     23618
#                        macro avg     0.9405    0.9267    0.9306     23618
#                     weighted avg     0.9933    0.9951    0.9941     23618
#
# Evaluate model on the valid set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9304    0.9835    0.9562      2786
#                     CENTRO_SALUD     1.0000    1.0000    1.0000        11
#               CORREO_ELECTRONICO     0.9590    0.9551    0.9571       245
#           EDAD_SUJETO_ASISTENCIA     0.9521    0.9641    0.9580      1030
#     FAMILIARES_SUJETO_ASISTENCIA     0.7266    0.7266    0.7266       128
#                           FECHAS     0.9770    0.8986    0.9361      1085
#                         HOSPITAL     0.9674    0.9175    0.9418       582
#                 ID_ASEGURAMIENTO     0.9913    0.9709    0.9810       584
#          ID_CONTACTO_ASISTENCIAL     0.8889    1.0000    0.9412        32
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         5
#             ID_SUJETO_ASISTENCIA     0.9424    0.9145    0.9282       304
# ID_TITULACION_PERSONAL_SANITARIO     0.9567    0.9985    0.9772       664
#                      INSTITUCION     0.5122    0.5833    0.5455       252
#        NOMBRE_PERSONAL_SANITARIO     0.9643    0.8770    0.9186      1602
#         NOMBRE_SUJETO_ASISTENCIA     0.9949    0.9949    0.9949       782
#                       NUMERO_FAX     0.4118    0.4667    0.4375        15
#                  NUMERO_TELEFONO     0.6667    0.8889    0.7619        72
#          OTROS_SUJETO_ASISTENCIA     0.2000    0.0625    0.0952        16
#                             PAIS     0.9493    0.9656    0.9574       349
#                        PROFESION     0.0000    0.0000    0.0000         9
#           SEXO_SUJETO_ASISTENCIA     0.9676    0.9825    0.9750       456
#                       TERRITORIO     0.9599    0.9189    0.9389      1171
#
#                        micro avg     0.9367    0.9346    0.9356     12180
#                        macro avg     0.7690    0.7759    0.7695     12180
#                     weighted avg     0.9417    0.9346    0.9372     12180
#
# Generating plots for the train set
# Generating plots for the valid set
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/060_train.txt > ./output/_2019-05-15_14-01-31-113906/060_train.txt_conll_evaluation.txt
# /usr/local/lib/python3.6/dist-packages/neuroner
# shell_command: perl /usr/local/lib/python3.6/dist-packages/neuroner/conlleval < ./output/_2019-05-15_14-01-31-113906/060_valid.txt > ./output/_2019-05-15_14-01-31-113906/060_valid.txt_conll_evaluation.txt
# The last 47 epochs have not shown improvements on the validation set.
#
# Starting epoch 61
# Training completed in 963.95 seconds
# Evaluate model on the train set
#                                   precision    recall  f1-score   support
#
#                            CALLE     0.9987    0.9787    0.9886      5545
#                     CENTRO_SALUD     1.0000    1.0000    1.0000        29
#               CORREO_ELECTRONICO     0.9853    0.9895    0.9874       474
#           EDAD_SUJETO_ASISTENCIA     0.9909    0.9947    0.9928      2069
#     FAMILIARES_SUJETO_ASISTENCIA     0.9492    0.9947    0.9714       376
#                           FECHAS     0.9927    0.9934    0.9931      1514
#                         HOSPITAL     0.9113    0.9991    0.9532      1100
#                 ID_ASEGURAMIENTO     0.9957    0.9966    0.9961      1160
#          ID_CONTACTO_ASISTENCIAL     0.9747    1.0000    0.9872        77
#     ID_EMPLEO_PERSONAL_SANITARIO     0.0000    0.0000    0.0000         0
#             ID_SUJETO_ASISTENCIA     0.9917    0.9917    0.9917       600
# ID_TITULACION_PERSONAL_SANITARIO     0.9964    1.0000    0.9982      1398
#                      INSTITUCION     0.9551    0.9313    0.9430       320
#        NOMBRE_PERSONAL_SANITARIO     0.9985    0.9976    0.9981      3365
#         NOMBRE_SUJETO_ASISTENCIA     0.9987    1.0000    0.9994      1561
#                       NUMERO_FAX     0.9535    0.9111    0.9318        45
#                  NUMERO_TELEFONO     0.9568    0.9779    0.9673       136
#          OTROS_SUJETO_ASISTENCIA     0.9697    1.0000    0.9846        32
#                             PAIS     0.9823    0.9863    0.9843       731
#                        PROFESION     0.9804    0.9615    0.9709        52
#           SEXO_SUJETO_ASISTENCIA     0.9957    0.9989    0.9973       927
#                       TERRITORIO     0.9957    0.9905    0.9931      2107
#
#                        micro avg     0.9896    0.9904    0.9900     23618
#                        macro avg     0.9351    0.9406    0.9377     23618
#                     weighted avg     0.9901    0.9904    0.9901     23618
#
# Evaluate model on the valid set

# %% [markdown]
# ## Postprocess task

# %%
run = "" # the path on which the output data from NeuroNER is allocated
original_brat = "./data/deploy/"  # the path where we locate the test dataset
path_to_process = "./output/"+run+"/000_deploy.txt" # the path of the output file on which the entities are predicted by NeuroNER model
path_to_save = "./output/"+run+"/000_deploy_postprocessed.txt" # the path of the output file on which the post-processed data are saved
path_to_brat = "./data/deploy/" # the path on which the processed file is going to be saved on brat format
prefixes = ['nhc/', 'NHC/','nhc:', 'NHC:', 'nhc-', 'NHC-', 'cp:', 'CP:', 'cp-', 'CP-', 'nacimiento:'] # prefixes to be cleaned

# %%
postprocess(path_to_process, path_to_save, clear_ending_points=True, clear_prefixes=True, prefixes=prefixes)

# %%
neuromodel.conll_to_brat.conll_to_brat(path_to_save, path_to_save, original_brat, path_to_brat, overwrite=True)

# %% [markdown]
# Once the execution has finished, the final output should be placed in the folder indicated by "path_to_brat"
